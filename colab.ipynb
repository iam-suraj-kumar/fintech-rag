# %%
# !git clone https://github.com/iam-suraj-kumar/fintech-rag.git
# Out:
# Cloning into 'fintech-rag'...
# remote: Enumerating objects: 300, done.
# remote: Counting objects: 100% (300/300), done.
# remote: Compressing objects: 100% (134/134), done.
# remote: Total 300 (delta 161), reused 290 (delta 154), pack-reused 0 (from 0)
# Receiving objects: 100% (300/300), 432.70 KiB | 1.76 MiB/s, done.
# Resolving deltas: 100% (161/161), done.

# %%
# %cd fintech-rag
# Out:
# /content/fintech-rag

# %%
# !uv sync --dev
# Out:
# Using CPython 3.12.13 interpreter at: /usr/bin/python3
# Creating virtual environment at: .venv
# Resolved 197 packages in 21ms
# Prepared 188 packages in 1m 00s
# Installed 188 packages in 1.16s
#  + accelerate==1.14.0
#  + aiohappyeyeballs==2.7.1
#  + aiohttp==3.14.1
#  + aiolimiter==1.2.1
#  + aiosignal==1.4.0
#  + altair==6.2.2
#  + annotated-doc==0.0.4
#  + annotated-types==0.7.0
#  + anthropic==0.116.0
#  + antlr4-python3-runtime==4.9.3
#  + anyio==4.14.1
#  + attrs==26.1.0
#  + beautifulsoup4==4.15.0
#  + blinker==1.9.0
#  + cached-property==2.0.1
#  + cachetools==7.1.4
#  + certifi==2026.6.17
#  + charset-normalizer==3.4.9
#  + click==8.4.2
#  + colorlog==6.10.1
#  + cuda-bindings==13.3.1
#  + cuda-pathfinder==1.5.6
#  + cuda-toolkit==13.0.3.0
#  + defusedxml==0.7.1
#  + dill==0.4.1
#  + distro==1.9.0
#  + doclang==0.7.2
#  + docling==2.112.0
#  + docling-core==2.87.0
#  + docling-ibm-models==3.13.3
#  + docling-parse==7.8.0
#  + docling-slim==2.112.0
# ...

# %%
# !cp .env.example .env
# fill in PORTKEY_API_KEY, LLM_MODEL, EMBEDDING_MODEL

# %%
# !python -m ingestion.fetch_filing_pdf
# Out:
# 2026-07-15 19:28:13,573 __main__ INFO Fetching PDF for AAPL from https://d18rn0p25nwr6d.cloudfront.net/CIK-0000320193/c87043b9-5d89-4717-9f49-c4f9663d0061.pdf
# 2026-07-15 19:28:13,693 __main__ INFO Saved AAPL (1093835 bytes) to data/raw_pdf/AAPL.pdf

# %%
# !uv run python -m ingestion.chunk_filings_basic
# Out:
# /content/fintech-rag/ingestion/chunk_filings_basic.py:5: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.document_loaders import PyPDFLoader
# 2026-07-15 19:28:35,576 __main__ INFO Extracted 121 pages of text from data/raw_pdf/AAPL.pdf
# 2026-07-15 19:28:35,581 __main__ INFO Split AAPL into 44 sections
# 2026-07-15 19:28:35,751 __main__ INFO Chunked AAPL into 168 chunks (basic pipeline)
# 2026-07-15 19:28:35,755 __main__ INFO Wrote 168 chunks for AAPL to data/chunks_basic/AAPL.json

# %%
# !uv run python -m ingestion.chunk_filings_advanced
# Out:
# 2026-07-15 19:28:55,055 __main__ INFO Converting data/raw_pdf/AAPL.pdf with docling
# 2026-07-15 19:28:55,161 docling.datamodel.document INFO detected formats: [<InputFormat.PDF: 'pdf'>]
# 2026-07-15 19:28:55,229 docling.document_converter INFO Going to convert document batch...
# 2026-07-15 19:28:55,229 docling.document_converter INFO Initializing pipeline for StandardPdfPipeline with options hash 232dd41d6716a8665bf46e5b99b32743
# 2026-07-15 19:28:55,242 docling.models.factories.base_factory INFO Loading plugin 'docling_defaults'
# 2026-07-15 19:28:55,253 docling.models.factories INFO Registered picture descriptions: ['picture_description_vlm_engine', 'vlm', 'api']
# 2026-07-15 19:28:55,265 docling.models.factories.base_factory INFO Loading plugin 'docling_defaults'
# 2026-07-15 19:28:55,316 docling.models.factories INFO Registered ocr engines: ['auto', 'easyocr', 'kserve_v2_ocr', 'nemotron-ocr', 'ocrmac', 'rapidocr', 'tesserocr', 'tesseract']
# ...

# %%
# !uv run python -m ingestion.index_comparison_collections
# Out:
# 2026-07-15 19:57:02,169 ingestion.index_to_qdrant INFO Collection 'sec_filings_basic' already exists
# 2026-07-15 19:57:02,383 ingestion.index_to_qdrant INFO Loaded 168 chunks for AAPL from data/chunks_basic
# 2026-07-15 19:57:04,139 portkey_ai._vendor.openai._base_client INFO Retrying request to /embeddings in 0.474396 seconds
# Traceback (most recent call last):
#   File "/content/fintech-rag/.venv/lib/python3.12/site-packages/httpx/_transports/default.py", line 101, in map_httpcore_exceptions
#     yield
#   File "/content/fintech-rag/.venv/lib/python3.12/site-packages/httpx/_transports/default.py", line 250, in handle_request
#     resp = self._pool.handle_request(req)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/fintech-rag/.venv/lib/python3.12/site-packages/httpcore/_sync/connection_pool.py", line 256, in handle_request
#     raise exc from None
# ...

# %%
# !uv run streamlit run ui/app.py
# Out:
# --2026-07-15 19:39:00--  https://github.com/
# Resolving github.com (github.com)... 140.82.114.3
# Connecting to github.com (github.com)|140.82.114.3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘index.html.4’
#
# index.html.4            [  <=>               ] 564.51K  1.86MB/s    in 0.3s
#
# 2026-07-15 19:39:01 (1.86 MB/s) - ‘index.html.4’ saved [578055]
#
# tar: bore-v0.5.1-x86_64-unknown-linux-musl.tar.gz: Cannot open: No such file or directory
# tar: Error is not recoverable: exiting now
# /bin/bash: line 1: ./bore: No such file or directory
#
# ...
#
# 2026-07-15 19:39:02.396 Uvicorn server started on :::8501
#
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.28.0.12:8501
#   External URL: http://34.16.208.224:8501
#
#   Stopping...
