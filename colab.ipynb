# %%
# !git clone https://github.com/iam-suraj-kumar/fintech-rag.git
# Out:
# Cloning into 'fintech-rag'...
# remote: Enumerating objects: 297, done.
# remote: Counting objects: 100% (297/297), done.
# remote: Compressing objects: 100% (131/131), done.
# remote: Total 297 (delta 160), reused 291 (delta 154), pack-reused 0 (from 0)
# Receiving objects: 100% (297/297), 431.41 KiB | 4.45 MiB/s, done.
# Resolving deltas: 100% (160/160), done.

# %%
# !cd fintech-rag && uv sync --dev
# Out:
# Using CPython 3.12.13 interpreter at: /usr/bin/python3
# Creating virtual environment at: .venv
# Resolved 197 packages in 24ms
# ⠧ Preparing packages... (181/188)

# %%
# !cp .env.example .env          # fill in API keys

# %%
# !python -m ingestion.fetch_filing_pdf

# %%
# !python -m ingestion.chunk_filings_basic

# %%
# !python -m ingestion.chunk_filings_advanced

# %%
# !python -m ingestion.index_comparison_collections

# %%
# !!streamlit run app.py &>/content/logs.txt & npx localtunnel --port 8501
