# %%
# !uv sync --dev
# Out:
# Resolved 197 packages in 3ms
# Uninstalled 39 packages in 552ms
# Installed 12 packages in 52ms
#  - anyio==4.14.2
#  + anyio==4.14.1
#  - appnope==0.1.4
#  - asttokens==3.0.2
#  - comm==0.2.3
#  - debugpy==1.8.21
#  - decorator==5.3.1
#  - doclang==0.7.3
#  + doclang==0.7.2
#  - docling==2.113.0
#  + docling==2.112.0
#  - docling-core==2.87.1
#  + docling-core==2.87.0
#  - docling-slim==2.113.0
#  + docling-slim==2.112.0
#  - executing==2.2.1
#  - faker==40.31.0
#  + faker==40.28.1
#  - gitpython==3.1.51
#  + gitpython==3.1.50
#  - iniconfig==2.3.0
#  - ipykernel==7.3.0
#  - ipython==9.15.0
#  - ipython-pygments-lexers==1.1.1
#  - jedi==0.20.0
#  - jupyter-client==8.9.1
#  - jupyter-core==5.9.1
#  - langsmith==0.10.5
#  + langsmith==0.10.2
#  - matplotlib-inline==0.2.2
#  - narwhals==2.24.0
#  + narwhals==2.23.0
#  - nest-asyncio2==1.7.2
#  - parso==0.8.7
#  - pexpect==4.9.0
#  - platformdirs==4.10.0
#  - prompt-toolkit==3.0.52
#  - ptyprocess==0.7.0
#  - pure-eval==0.2.3
#  - pyarrow==24.0.0
#  + pyarrow==25.0.0
#  - pypdfium2==5.12.0
#  + pypdfium2==5.11.0
#  - pytest==9.1.1
#  - pyzmq==27.1.0
#  - stack-data==0.6.3
#  - streamlit==1.59.2
#  + streamlit==1.59.1
#  - tornado==6.5.7
#  - traitlets==5.15.1
#  - wcwidth==0.8.2

# %%
# !cp .env.example .env
# fill in PORTKEY_API_KEY, LLM_MODEL, EMBEDDING_MODEL

# %%
# !python -m ingestion.fetch_filing_pdf
# Out:
# 2026-07-16 01:38:52,379 __main__ INFO Fetching PDF for AAPL from https://d18rn0p25nwr6d.cloudfront.net/CIK-0000320193/c87043b9-5d89-4717-9f49-c4f9663d0061.pdf
# 2026-07-16 01:38:52,757 __main__ INFO Saved AAPL (1093835 bytes) to data/raw_pdf/AAPL.pdf

# %%
# !uv run python -m ingestion.chunk_filings_basic
# Out:
# /Users/suraj/temp/fintech-rag/ingestion/chunk_filings_basic.py:5: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.document_loaders import PyPDFLoader
# 2026-07-16 01:39:09,623 __main__ INFO Extracted 121 pages of text from data/raw_pdf/AAPL.pdf
# 2026-07-16 01:39:09,624 __main__ INFO Split AAPL into 44 sections
# 2026-07-16 01:39:09,679 __main__ INFO Chunked AAPL into 168 chunks (basic pipeline)
# 2026-07-16 01:39:09,680 __main__ INFO Wrote 168 chunks for AAPL to data/chunks_basic/AAPL.json

# %%
# !uv run python -m ingestion.chunk_filings_advanced
# Out:
# 2026-07-16 01:39:55,000 __main__ INFO Converting data/raw_pdf/AAPL.pdf with docling
# 2026-07-16 01:39:55,015 docling.datamodel.document INFO detected formats: [<InputFormat.PDF: 'pdf'>]
# 2026-07-16 01:39:55,044 docling.document_converter INFO Going to convert document batch...
# 2026-07-16 01:39:55,044 docling.document_converter INFO Initializing pipeline for StandardPdfPipeline with options hash 232dd41d6716a8665bf46e5b99b32743
# 2026-07-16 01:39:55,048 docling.models.factories.base_factory INFO Loading plugin 'docling_defaults'
# 2026-07-16 01:39:55,052 docling.models.factories INFO Registered picture descriptions: ['picture_description_vlm_engine', 'vlm', 'api']
# 2026-07-16 01:39:55,054 docling.models.factories.base_factory INFO Loading plugin 'docling_defaults'
# 2026-07-16 01:39:55,070 docling.models.factories INFO Registered ocr engines: ['auto', 'easyocr', 'kserve_v2_ocr', 'nemotron-ocr', 'ocrmac', 'rapidocr', 'tesserocr', 'tesseract']
# 2026-07-16 01:39:55,524 docling.models.stages.ocr.auto_ocr_model INFO ocrmac cannot be used because ocrmac is not installed.
# 2026-07-16 01:39:57,309 docling.utils.accelerator_utils INFO Accelerator device: 'mps'
# [INFO] 2026-07-16 01:39:57,318 [RapidOCR] base.py:23: Using engine_name: onnxruntime
# [INFO] 2026-07-16 01:39:57,327 [RapidOCR] download_file.py:60: File exists and is valid: /Users/suraj/temp/fintech-rag/.venv/lib/python3.14/site-packages/rapidocr/models/PP-OCRv6_det_small.onnx
# [INFO] 2026-07-16 01:39:57,327 [RapidOCR] main.py:63: Using /Users/suraj/temp/fintech-rag/.venv/lib/python3.14/site-packages/rapidocr/models/PP-OCRv6_det_small.onnx
# [INFO] 2026-07-16 01:39:57,342 [RapidOCR] base.py:23: Using engine_name: onnxruntime
# [INFO] 2026-07-16 01:39:57,344 [RapidOCR] download_file.py:60: File exists and is valid: /Users/suraj/temp/fintech-rag/.venv/lib/python3.14/site-packages/rapidocr/models/ch_ppocr_mobile_v2.0_cls_mobile.onnx
# [INFO] 2026-07-16 01:39:57,344 [RapidOCR] main.py:63: Using /Users/suraj/temp/fintech-rag/.venv/lib/python3.14/site-packages/rapidocr/models/ch_ppocr_mobile_v2.0_cls_mobile.onnx
# [INFO] 2026-07-16 01:39:57,355 [RapidOCR] base.py:23: Using engine_name: onnxruntime
# [INFO] 2026-07-16 01:39:57,364 [RapidOCR] download_file.py:60: File exists and is valid: /Users/suraj/temp/fintech-rag/.venv/lib/python3.14/site-packages/rapidocr/models/PP-OCRv6_rec_small.onnx
# [INFO] 2026-07-16 01:39:57,364 [RapidOCR] main.py:63: Using /Users/suraj/temp/fintech-rag/.venv/lib/python3.14/site-packages/rapidocr/models/PP-OCRv6_rec_small.onnx
# 2026-07-16 01:39:57,383 docling.models.stages.ocr.auto_ocr_model INFO Auto OCR model selected rapidocr with onnxruntime.
# 2026-07-16 01:39:57,385 docling.models.factories.base_factory INFO Loading plugin 'docling_defaults'
# 2026-07-16 01:39:57,389 docling.models.factories INFO Registered layout engines: ['layout_object_detection', 'docling_layout_default', 'docling_experimental_table_crops_layout']
# 2026-07-16 01:39:57,398 docling.utils.accelerator_utils INFO Accelerator device: 'mps'
# 2026-07-16 01:39:57,767 httpx INFO HTTP Request: GET https://huggingface.co/api/models/docling-project/docling-layout-heron/revision/main "HTTP/1.1 200 OK"
# Loading weights: 100%|█████████████████████| 770/770 [00:00<00:00, 4340.40it/s]
# 2026-07-16 01:39:58,159 docling.models.factories.base_factory INFO Loading plugin 'docling_defaults'
# 2026-07-16 01:39:58,166 docling.models.factories INFO Registered table structure engines: ['docling_tableformer', 'docling_tableformer_v2', 'granite_vision_table']
# 2026-07-16 01:39:58,485 httpx INFO HTTP Request: GET https://huggingface.co/api/models/docling-project/docling-models/revision/v2.3.0 "HTTP/1.1 200 OK"
# 2026-07-16 01:39:58,528 docling.utils.accelerator_utils INFO Accelerator device: 'mps'
# 2026-07-16 01:39:58,759 docling.pipeline.base_pipeline INFO Processing document AAPL.pdf
# 2026-07-16 01:40:48,309 docling.document_converter INFO Finished converting document AAPL.pdf in 53.29 sec.
# 2026-07-16 01:40:48,605 __main__ INFO Chunked AAPL into 310 chunks (advanced pipeline)
# 2026-07-16 01:40:48,608 __main__ INFO Wrote 310 chunks for AAPL to data/chunks_advanced/AAPL.json

# %%
# !uv run python -m ingestion.index_comparison_collections
# Out:
# 2026-07-16 01:40:51,882 ingestion.index_to_qdrant INFO Creating collection 'sec_filings_basic'
# 2026-07-16 01:40:51,925 ingestion.index_to_qdrant INFO Loaded 168 chunks for AAPL from data/chunks_basic
# 2026-07-16 01:40:54,856 httpx INFO HTTP Request: POST https://api.portkey.ai/v1/embeddings "HTTP/1.1 200 OK"
# 2026-07-16 01:40:56,283 ingestion.index_to_qdrant INFO Embedded 168 chunks for AAPL (dense + sparse)
# 2026-07-16 01:40:56,392 ingestion.index_to_qdrant INFO Upserted 168 points for AAPL into 'sec_filings_basic'
# 2026-07-16 01:40:56,393 ingestion.index_to_qdrant INFO Creating collection 'sec_filings_advanced'
# 2026-07-16 01:40:56,395 ingestion.index_to_qdrant INFO Loaded 310 chunks for AAPL from data/chunks_advanced
# 2026-07-16 01:40:58,390 httpx INFO HTTP Request: POST https://api.portkey.ai/v1/embeddings "HTTP/1.1 200 OK"
# 2026-07-16 01:41:00,194 ingestion.index_to_qdrant INFO Embedded 310 chunks for AAPL (dense + sparse)
# 2026-07-16 01:41:00,381 ingestion.index_to_qdrant INFO Upserted 310 points for AAPL into 'sec_filings_advanced'

# %%
# !uv run streamlit run ui/app.py
# Out:
# 2026-07-16 01:41:02.180 Uvicorn server started on :::8501
#
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://192.168.1.52:8501
#
#   Help agents write better Streamlit apps?
#   Install the official Streamlit skills by running streamlit skills in your terminal.
#
#   For better performance, install the Watchdog module:
#
#   $ xcode-select --install
#   $ pip install watchdog
#
# 2026-07-16 01:41:06,074 core.rag INFO answer_question: strategy='baseline' collection=None question="What was Apple's total net sales for fiscal year 2024?"
# 2026-07-16 01:41:06,074 core.retrieval INFO hybrid_search: collection='sec_filings_advanced' top_k=8 query="What was Apple's total net sales for fiscal year 2024?"
# 2026-07-16 01:41:07,197 httpx INFO HTTP Request: POST https://api.portkey.ai/v1/embeddings "HTTP/1.1 200 OK"
# 2026-07-16 01:41:07,496 core.retrieval INFO hybrid_search: retrieved 8 points from 'sec_filings_advanced'
# 2026-07-16 01:41:10,270 httpx INFO HTTP Request: POST https://api.portkey.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-07-16 01:41:10,271 core.rag INFO answer_question: 8 chunks retrieved, 4 cited, 2324 input tokens, 33 output tokens
# 2026-07-16 01:41:13,353 core.rag INFO answer_question: strategy='baseline' collection=None question='What new products did Apple launch in fiscal 2024, and how did they affect segment performance?'
# 2026-07-16 01:41:13,353 core.retrieval INFO hybrid_search: collection='sec_filings_advanced' top_k=8 query='What new products did Apple launch in fiscal 2024, and how did they affect segment performance?'
# 2026-07-16 01:41:13,955 httpx INFO HTTP Request: POST https://api.portkey.ai/v1/embeddings "HTTP/1.1 200 OK"
# 2026-07-16 01:41:14,153 core.retrieval INFO hybrid_search: retrieved 8 points from 'sec_filings_advanced'
# 2026-07-16 01:41:18,053 httpx INFO HTTP Request: POST https://api.portkey.ai/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-07-16 01:41:18,054 core.rag INFO answer_question: 8 chunks retrieved, 5 cited, 3280 input tokens, 300 output tokens
